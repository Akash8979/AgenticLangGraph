# %%
# Read file line by line

with open('../../../../Desktop/#product_ai.txt') as f:
    print(f.readline())
    print(f.readline())
    print(f.readline())
# Out:
# #product_ai
#
# from datetime import datetime
#
# from pathlib import Path

# %%
# Read entire file once
with open('../../../../Desktop/#product_ai.txt') as f:
    #print(f.read()) when want to read entire file
    print(f.read(105)) # when you want to read some number of files.
# Out:
# #product_ai
# from datetime import datetime
# from pathlib import Path
#
# import os
#
# import logging.config
# from

# %%
# Read entire file once
with open('../../../../Desktop/#product_ai.txt') as f:
    pass
    # for x in f:
    #     print(x) when you want to loop through file line by line

# %%
# write new file or add text to existing file

with open('../../../../Downloads/demo.txt','w') as f:
    f.write("Hello world")

# %%
# append new content in existing file
with open('../../../../Downloads/demo.txt','a') as f:
    f.write('Hello World 2')


with open('../../../../Downloads/demo.txt','r') as f:
    print(f.read())
# Out:
# Hello World 2

# %%
# check if file exist or not
import os

if os.path.exists('../../../../Downloads/demo.txt'):
    # deleting a file
    os.remove('../../../../Downloads/demo.txt')
    # os.rmdir("myfolder"). , to delete a folder
else:
    print('File does not exist.')
# Out:
# File does not exist.
